# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train = pd.DataFrame(pd.read_csv("train.csv"))
test = pd.DataFrame(pd.read_csv("test.csv"))

# %%
train
# Out:
#             ID  VIN (1-10)     County        City State  ZIP Code  Model Year  \
# 0      EV33174  5YJ3E1EC6L  Snohomish    LYNNWOOD    WA   98037.0      2020.0
# 1      EV40247  JN1AZ0CP8B     Skagit  BELLINGHAM    WA   98229.0      2011.0
# 2      EV12248  WBY1Z2C56F     Pierce      TACOMA    WA   98422.0      2015.0
# 3      EV55713  1G1RD6E44D       King     REDMOND    WA   98053.0      2013.0
# 4      EV28799  1G1FY6S05K     Pierce    PUYALLUP    WA   98375.0      2019.0
# ...        ...         ...        ...         ...   ...       ...         ...
# 64348   EV6357  KNDCE3LG7L       King     SEATTLE    WA   98144.0      2020.0
# 64349    EV423  JTDKN3DP2D     Pierce      TACOMA    WA   98402.0      2013.0
# 64350  EV27852  1G1FX6S05J       King     SEATTLE    WA   98119.0      2018.0
# 64351    EV830  WP1AE2A24H       King     SEATTLE    WA   98115.0      2017.0
# 64352  EV11120  1N4BZ1CP8K      Lewis      TOLEDO    WA   98591.0      2019.0
#
# ...

# %%
test
# Out:
#             ID  VIN (1-10)     County           City State  ZIP Code  \
# 0      EV28368  JN1AZ0CP5C  Jefferson  PORT TOWNSEND    WA   98368.0
# 1      EV27088  1FTFW1ED1M       King       ISSAQUAH    WA   98029.0
# 2      EV58989  5YJ3E1EB9J     Pierce       PUYALLUP    WA   98372.0
# 3       EV6715  5YJ3E1EB0M     Pierce         TACOMA    WA   98403.0
# 4      EV63251  5YJYGDEF1M     Kitsap      BREMERTON    WA   98312.0
# ...        ...         ...        ...            ...   ...       ...
# 27575  EV16462  1FADP5CU8G      Clark  BRUSH PRAIRIE    WA   98606.0
# 27576  EV19258  1G1RB6E47C       King         RENTON    WA   98058.0
# 27577  EV91826  7SAYGDEE3N       King       BELLEVUE    WA   98006.0
# 27578   EV5443  1G1FW6S05H   Thurston        OLYMPIA    WA   98501.0
# 27579  EV12031  JN1AZ0CP6B  Snohomish        EDMONDS    WA   98026.0
#
#        Model Year       Make    Model                   Electric Vehicle Type  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l1 = LabelEncoder()
l2 = LabelEncoder()
l3 = LabelEncoder()
l4 = LabelEncoder()
l5 = LabelEncoder()
l6 = LabelEncoder()
l7 = LabelEncoder()
l8 = LabelEncoder()
l9 = LabelEncoder()
l10 = LabelEncoder()
l11 = LabelEncoder()
l12 = LabelEncoder()
l13 = LabelEncoder()
l14 = LabelEncoder()
l15 = LabelEncoder()
l16 = LabelEncoder()
l17 = LabelEncoder()
l18 = LabelEncoder()

# %%
train['ID'] = l1.fit_transform(train['ID'])
train['VIN (1-10)'] = l2.fit_transform(train['VIN (1-10)'])
train['County'] = l3.fit_transform(train['County'])
train['City'] = l4.fit_transform(train['City'])
train['State'] = l5.fit_transform(train['State'])
train['ZIP Code'] = l6.fit_transform(train['ZIP Code'])
train['Model Year'] = l7.fit_transform(train['Model Year'])
train['Make'] = l8.fit_transform(train['Make'])
train['Model'] = l9.fit_transform(train['Model'])
train['Electric Vehicle Type'] = l10.fit_transform(train['Electric Vehicle Type'])
train['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] = l11.fit_transform(train['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])
train['Electric Range'] = l12.fit_transform(train['Electric Range'])
train['Base MSRP'] = l13.fit_transform(train['Base MSRP'])
train['Legislative District'] = l14.fit_transform(train['Legislative District'])
train['DOL Vehicle ID'] = l15.fit_transform(train['DOL Vehicle ID'])
train['Vehicle Location'] = l16.fit_transform(train['Vehicle Location'])
train['Electric Utility'] = l17.fit_transform(train['Electric Utility'])
train['Expected Price ($1k)'] = l18.fit_transform(train['Expected Price ($1k)'])

# %%
from sklearn.preprocessing import LabelEncoder
ll1 = LabelEncoder()
ll2 = LabelEncoder()
ll3 = LabelEncoder()
ll4 = LabelEncoder()
ll5 = LabelEncoder()
ll6 = LabelEncoder()
ll7 = LabelEncoder()
ll8 = LabelEncoder()
ll9 = LabelEncoder()
ll10 = LabelEncoder()
ll11 = LabelEncoder()
ll12 = LabelEncoder()
ll13 = LabelEncoder()
ll14 = LabelEncoder()
ll15 = LabelEncoder()
ll16 = LabelEncoder()
ll17 = LabelEncoder()

# %%
test['ID'] = ll1.fit_transform(test['ID'])
test['VIN (1-10)'] = ll2.fit_transform(test['VIN (1-10)'])
test['County'] = ll3.fit_transform(test['County'])
test['City'] = ll4.fit_transform(test['City'])
test['State'] = ll5.fit_transform(test['State'])
test['ZIP Code'] = ll6.fit_transform(test['ZIP Code'])
test['Model Year'] = ll7.fit_transform(test['Model Year'])
test['Make'] = ll8.fit_transform(test['Make'])
test['Model'] = ll9.fit_transform(test['Model'])
test['Electric Vehicle Type'] = ll10.fit_transform(test['Electric Vehicle Type'])
test['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] = ll11.fit_transform(test['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])
test['Electric Range'] = ll12.fit_transform(test['Electric Range'])
test['Base MSRP'] = ll13.fit_transform(test['Base MSRP'])
test['Legislative District'] = ll14.fit_transform(test['Legislative District'])
test['DOL Vehicle ID'] = ll15.fit_transform(test['DOL Vehicle ID'])
test['Vehicle Location'] = ll16.fit_transform(test['Vehicle Location'])
test['Electric Utility'] = ll17.fit_transform(test['Electric Utility'])

# %%
train
# Out:
#           ID  VIN (1-10)  County  City  State  ZIP Code  Model Year  Make  \
# 0      18053        1914     120   271     35       191          16    28
# 1      23497        3067     118    38     35       269           7    22
# 2       1753        4682      95   473     35       393          11     3
# 3      35557         636      60   391     35       202           9     5
# 4      14667         318      95   380     35       367          15     5
# ...      ...         ...     ...   ...    ...       ...         ...   ...
# 64348  41670        3851      60   433     35       243          16    15
# 64349  25124        3150      95   473     35       383           9    30
# 64350  13905         277      60   433     35       234          14     5
# 64351  56747        5264      60   433     35       230          13    24
# 64352    890        1042      69   481     35       461          15    22
#
#        Model  Electric Vehicle Type  \
# 0         57                      0
# ...

# %%
test
# Out:
#           ID  VIN (1-10)  County  City  State  ZIP Code  Model Year  Make  \
# 0       6081        2593      36   280     28       258           4    20
# 1       5685         150      38   160     28        92          13     9
# 2      16343        1625      57   287     28       261          10    26
# 3      19109        1583      57   364     28       279          13    26
# 4      17745        2388      39    32     28       224          13    26
# ...      ...         ...     ...   ...    ...       ...         ...   ...
# 27575   2141         102      17    36     28       356           8     9
# 27576   3055         417      38   296     28       114           4     5
# 27577  27292        2443      38    22     28        75          14    26
# 27578  14785         184      77   253     28       302           9     5
# 27579    675        2594      72   102     28        89           3    20
#
#        Model  Electric Vehicle Type  \
# 0         50                      0
# ...

# %%
independent= pd.DataFrame(train.drop(["Expected Price ($1k)"],axis=1))
independent
# Out:
#           ID  VIN (1-10)  County  City  State  ZIP Code  Model Year  Make  \
# 0      18053        1914     120   271     35       191          16    28
# 1      23497        3067     118    38     35       269           7    22
# 2       1753        4682      95   473     35       393          11     3
# 3      35557         636      60   391     35       202           9     5
# 4      14667         318      95   380     35       367          15     5
# ...      ...         ...     ...   ...    ...       ...         ...   ...
# 64348  41670        3851      60   433     35       243          16    15
# 64349  25124        3150      95   473     35       383           9    30
# 64350  13905         277      60   433     35       234          14     5
# 64351  56747        5264      60   433     35       230          13    24
# 64352    890        1042      69   481     35       461          15    22
#
#        Model  Electric Vehicle Type  \
# 0         57                      0
# ...

# %%
dependent= pd.DataFrame(train["Expected Price ($1k)"])
dependent
# Out:
#        Expected Price ($1k)
# 0                       154
# 1                        27
# 2                        40
# 3                       115
# 4                       136
# ...                     ...
# 64348                   110
# 64349                    19
# 64350                    69
# 64351                   146
# 64352                   118
#
# [64353 rows x 1 columns]

# %%
X,x,Y,y = train_test_split(independent,dependent,test_size=0.25,random_state=200)

# %%
from sklearn import linear_model
# independent, dependent
# test
model1 = linear_model.LinearRegression()
model1.fit(independent,dependent)
model1.score(x,y)
# Out:
# 0.4779369765927479

# %%
prediction = model1.predict(test)

# %%
prediction
# Out:
# array([[ 11.20057226],
#        [ 85.66478261],
#        [ 93.90663266],
#        ...,
#        [130.79068981],
#        [ 35.21711743],
#        [  0.17604397]])

# %%
from sklearn.preprocessing import MaxAbsScaler
sc = MaxAbsScaler()
X_t = sc.fit_transform(X)
x_t = sc.fit_transform(x)

# %%
model1.fit(X_t,Y)
# Out:
# LinearRegression()

# %%
print(model1.score(x_t,y))
# Out:
# 0.4777187052727516

# %%
# Out:
# array([[1.00000e+00, 3.50460e+04, 2.15000e+03, ..., 2.80900e+05,
#         1.59000e+04, 9.00000e+02],
#        [1.00000e+00, 4.02950e+04, 2.17300e+03, ..., 1.07584e+05,
#         2.16480e+04, 4.35600e+03],
#        [1.00000e+00, 1.76330e+04, 1.71000e+03, ..., 6.35040e+04,
#         1.63800e+04, 4.22500e+03],
#        ...,
#        [1.00000e+00, 3.25160e+04, 2.19900e+03, ..., 1.46410e+04,
#         4.23500e+03, 1.22500e+03],
#        [1.00000e+00, 6.16220e+04, 1.17900e+03, ..., 8.52640e+04,
#         1.92720e+04, 4.35600e+03],
#        [1.00000e+00, 3.62050e+04, 3.31000e+02, ..., 7.23610e+04,
#         1.77540e+04, 4.35600e+03]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2,include_bias=True)
X_tt = poly.fit_transform(X)
x_tt = poly.transform(x)

model1.fit(X_tt,Y)
y_pred = model1.predict(x_tt)
print(model1.score(x_tt,y))
# Out:
# 0.6715984333075967

# %%
y_pred
# Out:
# array([[ 97.13357989],
#        [ 13.72886626],
#        [ 75.10090077],
#        ...,
#        [171.47243792],
#        [ 76.29828639],
#        [149.89104842]])
